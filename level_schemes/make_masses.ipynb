# %%
import pandas as pd
import os

# %%
m_n = 939565.421 # keV
m_p = 938272.089 # keV
df = pd.read_csv('BE_A_from_NuDat3.csv')
df.head()
# Out:
#    z  n  a name   BE_A_keV  BE_A_unc_keV
# 0  0  1  1    n     0.0000        0.0000
# 1  1  0  1    H     0.0000        0.0000
# 2  2  2  4   He  7073.9156        0.0002
# 3  3  3  6   Li  5332.3312        0.0003
# 4  3  4  7   Li  5606.4401        0.0006

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   z             52 non-null     int64
#  1   n             52 non-null     int64
#  2   a             52 non-null     int64
#  3   name          52 non-null     object
#  4   BE_A_keV      52 non-null     float64
#  5   BE_A_unc_keV  52 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 2.6+ KB

# %%
df['Mass_MeV'] = (df['z']*m_p + df['n']*m_n - df['BE_A_keV']*(df['z'] + df['n']))/1e3
df.to_csv('BE_A_from_NuDat3.csv', index=False)
df
# Out:
#      z   n   a name   BE_A_keV  BE_A_unc_keV      Mass_MeV
# 0    0   1   1    n     0.0000        0.0000    939.565421
# 1    1   0   1    H     0.0000        0.0000    938.272089
# 2    2   2   4   He  7073.9156        0.0002   3727.379358
# 3    3   3   6   Li  5332.3312        0.0003   5601.518543
# 4    3   4   7   Li  5606.4401        0.0006   6533.832870
# 5    4   5   9   Be  6462.6693        0.0085   8392.751437
# 6    5   5  10    B  6475.0835        0.0015   9324.436715
# 7    5   6  11    B  6927.7323        0.0011  10252.547916
# 8    6   6  12    C  7680.1446        0.0002  11174.863325
# 9    6   7  13    C  7469.8495        0.0002  12109.482437
# 10   7   7  14    N  7475.6148        0.0002  13040.203963
# 11   7   8  15    N  7699.4603        0.0002  13968.936086
# 12   8   8  16    O  7976.2072        0.0002  14895.080765
# 13   8   9  17    O  7750.7291        0.0002  15830.503106
# 14   8  10  18    O  7767.0981        0.0002  16762.023156
# ...
